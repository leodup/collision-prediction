# %%
import os
import torch
import imageio.v3 as iio
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader

def adjust_video_length(video, desired_frames):
    current_frames = video.shape[0]
    
    if current_frames < desired_frames:
        pad_frames = desired_frames - current_frames
        padding = torch.zeros((pad_frames, *video.shape[1:]), dtype=video.dtype)
        video = torch.cat((video, padding), dim=0)
    elif current_frames > desired_frames:
        video = video[:desired_frames]
    
    return video

from PIL import Image

def is_image_valid(image_path):
    try:
        img = Image.open(image_path)
        img.verify()
        return True
    except:
        return False


import os
import numpy as np
from torch.utils.data import Dataset
from torchvision.transforms import ToTensor
from PIL import Image

class VideoDataset(Dataset):
    def __init__(self, directory):
        self.directory = directory
        self.video_dirs = sorted([d for d in os.listdir(directory) if os.path.isdir(os.path.join(directory, d))])

    def __len__(self):
        return len(self.video_dirs)

    def __getitem__(self, idx):
        video_dir = os.path.join(self.directory, self.video_dirs[idx])
        frames = []
        for i in range(22):
            image_path = os.path.join(video_dir, f"image_{i}.png")
            if is_image_valid(image_path):
              image = Image.open(image_path).convert("RGB")
              frames.append(ToTensor()(image))
        video = torch.stack(frames)
        # Adjust video length
        desired_frames = 22  
        video = adjust_video_length(video, desired_frames)
        return video

class SegmentationDataset(Dataset):
    def __init__(self, directory):
        self.directory = directory
        self.video_dirs = sorted([d for d in os.listdir(directory) if os.path.isdir(os.path.join(directory, d))])

    def __len__(self):
        return len(self.video_dirs)

    def __getitem__(self, idx):
        video_dir = os.path.join(self.directory, self.video_dirs[idx])
        frames = []
        for i in range(22):
            image_path = os.path.join(video_dir, f"image_{i}.png")
            if is_image_valid(image_path):
                image = Image.open(image_path).convert("RGB")
                frames.append(ToTensor()(image))

        mask_path = os.path.join(video_dir, "mask.npy")
        mask_data = np.load(mask_path)
        mask = torch.tensor(mask_data.reshape(22, 160, 240), dtype=torch.long)  # Reshape the mask data
        video = torch.stack(frames)
        # Adjust video length
        desired_frames = 22  
        video = adjust_video_length(video, desired_frames)
        return video, mask




import os
import numpy as np

def save_generated_masks(generated_masks, output_directory):
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    for i, mask in enumerate(generated_masks):
        output_path = os.path.join(output_directory, f"mask_{i}.npy")
        np.save(output_path, mask)


def calculate_iou(predictions, masks):
    intersection = torch.sum(predictions & masks)
    union = torch.sum(predictions | masks)
    iou = intersection / union
    return iou.item()


from tqdm.notebook import tqdm

# %%
if torch.cuda.is_available():
  device = torch.device("cuda:0")
else:
  device = torch.device("cpu")

# %%
device = torch.device("cpu")

# %%
num_epochs = 10

# %%
class PretextModel(nn.Module):
    def __init__(self):
        super(PretextModel, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv3d(22, 32, kernel_size=(3, 3, 3), padding=(1, 1, 1)),
            nn.ReLU(inplace=True),
            nn.MaxPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2)),
            nn.Conv3d(32, 64, kernel_size=(3, 3, 3), padding=(1, 1, 1)),
            nn.ReLU(inplace=True),
            nn.MaxPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2)),
        )
        
        self.decoder = nn.Sequential(
            nn.Conv3d(64, 32, kernel_size=(3, 3, 3), padding=(1, 1, 1)),
            nn.ReLU(inplace=True),
            nn.ConvTranspose3d(32, 32, kernel_size=(1, 2, 2), stride=(1, 2, 2)),
            nn.ReLU(inplace=True),
            nn.ConvTranspose3d(32, 22, kernel_size=(1, 2, 2), stride=(1, 2, 2)),
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

# %%
unlabeled_dataset = VideoDataset("/scratch/dks7920/Dataset_Student/unlabeled")
labeled_train_dataset = SegmentationDataset("/scratch/dks7920/Dataset_Student/train")
labeled_val_dataset = SegmentationDataset("/scratch/dks7920/Dataset_Student/val")

# %%
import time
from tqdm import trange

# Self-supervised learning
pretext_model = PretextModel().to(device)
criterion = nn.MSELoss().to(device)
optimizer = optim.Adam(pretext_model.parameters(), lr=0.001)

unlabeled_dataloader = DataLoader(unlabeled_dataset, batch_size=32, shuffle=True)
t = trange(num_epochs)
for epoch in t:
    start_epoch = time.time()

    for batch_idx, videos in enumerate(unlabeled_dataloader):
        start_batch = time.time()
        videos = videos.to(device)
        optimizer.zero_grad()

        start_forward = time.time()
        predictions = pretext_model(videos)

        start_loss = time.time()
        loss = criterion(predictions, videos)  # Modify this line based on the pretext task

        start_backward = time.time()
        loss.backward()

        start_optim = time.time()
        optimizer.step()

        batch_time = time.time() - start_batch
        t.set_postfix(batch_time=batch_time, batch_idx=batch_idx + 1)

    epoch_time = time.time() - start_epoch
    t.set_postfix(epoch_time=epoch_time, epoch=epoch + 1, refresh=True)
# Out:
#   0%|          | 0/10 [04:57<?, ?it/s, batch_idx=19, batch_time=0.0683]Exception ignored in: <generator object tqdm.__iter__ at 0x146386800900>
# Traceback (most recent call last):
#   File "/ext3/miniconda3/lib/python3.10/site-packages/tqdm/std.py", line 1179, in __iter__
#     yield obj
# KeyboardInterrupt:
#
# KeyboardInterrupt

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# %%
from torch.utils.data import Subset
num_samples = 10  # Adjust this to the number of samples you want to use
small_unlabeled_dataset = Subset(unlabeled_dataset, range(num_samples))
small_unlabeled_dataloader = DataLoader(small_unlabeled_dataset, batch_size=32, shuffle=True)

pretext_model = PretextModel().to(device)
criterion = nn.MSELoss().to(device)
optimizer = optim.Adam(pretext_model.parameters(), lr=0.001)

from tqdm import trange
import time

t = trange(num_epochs)
for epoch in t:
    start_epoch = time.time()

    for batch_idx, videos in enumerate(small_unlabeled_dataloader):
        start_batch = time.time()
        videos = videos.to(device)
        optimizer.zero_grad()

        start_forward = time.time()
        predictions = pretext_model(videos)

        start_loss = time.time()
        loss = criterion(predictions, videos)  # Modify this line based on the pretext task

        start_backward = time.time()
        loss.backward()

        start_optim = time.time()
        optimizer.step()

        batch_time = time.time() - start_batch
        t.set_postfix(batch_time=batch_time, batch_idx=batch_idx + 1)

    epoch_time = time.time() - start_epoch
    t.set_postfix(epoch_time=epoch_time, epoch=epoch + 1, refresh=True)
# Out:
# 100%|██████████| 10/10 [00:15<00:00,  1.56s/it, epoch=10, epoch_time=0.996]

# %%
class SegmentationModel(nn.Module):
    def __init__(self, pretrained_model):
        super(SegmentationModel, self).__init__()
        self.base_model = pretrained_model.encoder
        self.segmentation_head = nn.Sequential(
            nn.Conv3d(64, 32, kernel_size=(3, 3, 3), padding=(1, 1, 1)),
            nn.ReLU(inplace=True),
            nn.Upsample(size=(22, 160, 240), mode="nearest"),
            nn.Conv3d(32, 16, kernel_size=(3, 3, 3), padding=(1, 1, 1)),
            nn.ReLU(inplace=True),
            nn.Conv3d(16, 52, kernel_size=(3, 3, 3), padding=(1, 1, 1)),
        )

    def forward(self, x):
        x = self.base_model(x)
        x = self.segmentation_head(x)
        return x

# %%
# Supervised fine-tuning
segmentation_model = SegmentationModel(pretrained_model=pretext_model).to(device)
criterion = nn.CrossEntropyLoss().to(device)
optimizer = optim.Adam(segmentation_model.parameters(), lr=0.001)

train_dataloader = DataLoader(labeled_train_dataset, batch_size=16, shuffle=True)
val_dataloader = DataLoader(labeled_val_dataset, batch_size=16, shuffle=False)

for epoch in tqdm(range(num_epochs)):
    # Training loop
    segmentation_model.train()
    for videos, masks in train_dataloader:
        videos = videos.to(device)
        masks = masks.to(device)
        optimizer.zero_grad()
        predictions = segmentation_model(videos)
        loss = criterion(predictions, masks)
        loss.backward()
        optimizer.step()

    # Validation loop
    segmentation_model.eval()
    val_loss = 0
    with torch.no_grad():
        for videos, masks in val_dataloader:
            videos = videos.to(device)
            masks = masks.to(device)
            predictions = segmentation_model(videos)
            loss = criterion(predictions, masks)
            val_loss += loss.item()

    # Calculate average validation loss
    avg_val_loss = val_loss / len(val_dataloader)
    print(f"Epoch {epoch + 1}, Validation loss: {avg_val_loss:.4f}")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Mask path: /scratch/dks7920/Dataset_Student/train/video_715/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_849/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_322/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_892/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_194/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_447/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_583/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_64/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_951/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_418/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_281/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_991/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_559/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_325/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_231/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_553/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_269/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_864/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_664/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_241/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_366/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_313/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_343/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_370/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_23/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_602/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_495/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_52/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_610/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_356/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_770/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_881/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_510/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_916/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_253/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_943/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_459/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_587/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_859/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_558/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_146/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_948/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_808/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_830/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_385/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_873/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_208/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_44/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_456/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_729/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_74/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_880/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_657/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_821/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_505/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_390/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_103/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_303/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_432/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_823/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_394/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_999/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_570/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_530/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_145/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_262/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_930/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_29/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_120/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_674/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_157/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_121/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_307/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_186/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_691/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_288/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_451/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_354/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_152/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_457/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_403/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_857/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_711/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_8/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_340/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_380/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_389/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_501/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_496/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_597/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_555/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_250/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_333/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_245/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_476/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_178/mask.npy
# Mask data shape: (22, 160, 240)

# %%
print(device)

# %%
import numpy as np

def count_classes(dataset):
    unique_classes = set()
    for _, mask in dataset:
        for frame in mask:  # Iterate through each frame of the mask
            classes = np.unique(frame.numpy())
            unique_classes.update(classes)
    return len(unique_classes)

num_classes = count_classes(labeled_train_dataset)
print(f"Number of classes: {num_classes}")
# Out:
# Mask path: /scratch/dks7920/Dataset_Student/train/video_0/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_1/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_10/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_100/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_101/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_102/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_103/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_104/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_105/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_106/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_107/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_108/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_109/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_11/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_110/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_111/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_112/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_113/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_114/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_115/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_116/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_117/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_118/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_119/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_12/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_120/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_121/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_122/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_123/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_124/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_125/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_126/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_127/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_128/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_129/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_13/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_130/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_131/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_132/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_133/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_134/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_135/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_136/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_137/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_138/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_139/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_14/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_140/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_141/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_142/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_143/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_144/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_145/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_146/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_147/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_148/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_149/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_15/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_150/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_151/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_152/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_153/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_154/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_155/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_156/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_157/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_158/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_159/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_16/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_160/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_161/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_162/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_163/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_164/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_165/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_166/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_167/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_168/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_169/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_17/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_170/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_171/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_172/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_173/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_174/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_175/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_176/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_177/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_178/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_179/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_18/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_180/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_181/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_182/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_183/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_184/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_185/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_186/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_187/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_188/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_189/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_19/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_190/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_191/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_192/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_193/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_194/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_195/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_196/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_197/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_198/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_199/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_2/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_20/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_200/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_201/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_202/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_203/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_204/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_205/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_206/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_207/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_208/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_209/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_21/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_210/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_211/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_212/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_213/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_214/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_215/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_216/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_217/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_218/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_219/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_22/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_220/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_221/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_222/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_223/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_224/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_225/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_226/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_227/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_228/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_229/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_23/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_230/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_231/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_232/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_233/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_234/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_235/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_236/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_237/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_238/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_239/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_24/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_240/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_241/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_242/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_243/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_244/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_245/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_246/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_247/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_248/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_249/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_25/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_250/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_251/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_252/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_253/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_254/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_255/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_256/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_257/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_258/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_259/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_26/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_260/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_261/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_262/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video
mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_964/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_965/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_966/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_967/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_968/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_969/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_97/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_970/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_971/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_972/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_973/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_974/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_975/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_976/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_977/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_978/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_979/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_98/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_980/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_981/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_982/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_983/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_984/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_985/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_986/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_987/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_988/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_989/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_99/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_990/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_991/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_992/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_993/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_994/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_995/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_996/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_997/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_998/mask.npy
# Mask data shape: (22, 160, 240)
# Mask path: /scratch/dks7920/Dataset_Student/train/video_999/mask.npy
# Mask data shape: (22, 160, 240)
# Number of classes: 52

# %%
mask_data2 = np.load("/scratch/dks7920/Dataset_Student/train/video_301/mask.npy")
print(f"Mask data shape: {mask_data2.shape}")
# Out:
# Mask data shape: (22, 160, 240)

# %%
# 1. Implementing a custom pretext task
class NextFramePredictionModel(nn.Module):
    def __init__(self):
        super(NextFramePredictionModel, self).__init__()
        # Use the same encoder architecture as in the original code
        self.encoder = nn.Sequential(
            nn.Conv3d(22, 32, kernel_size=(3, 3, 3), padding=(1, 1, 1)),
            nn.ReLU(inplace=True),
            nn.MaxPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2)),
            nn.Conv3d(32, 64, kernel_size=(3, 3, 3), padding=(1, 1, 1)),
            nn.ReLU(inplace=True),
            nn.MaxPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2)),
        )
        
        # Use a different decoder architecture for the pretext task
        self.decoder = nn.Sequential(
            nn.Conv3d(64, 32, kernel_size=(3, 3, 3), padding=(1, 1, 1)),
            nn.ReLU(inplace=True),
            nn.ConvTranspose3d(32, 32, kernel_size=(1, 2, 2), stride=(1, 2, 2)),
            nn.ReLU(inplace=True),
            nn.ConvTranspose3d(32, 3, kernel_size=(1, 2, 2), stride=(1, 2, 2)),
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x


# Replace the pretext model with the new model
pretext_model = NextFramePredictionModel().to(device)
criterion = nn.MSELoss().to(device)

# Modify the pretext task training loop
for epoch in tqdm(range(num_epochs)):
    pretext_model.train()
    for videos in small_unlabeled_dataloader:
        videos = videos.to(device)
        optimizer.zero_grad()
        input_videos = videos[:, :-1]
        target_videos = videos[:, -1]
        predictions = pretext_model(input_videos)
        loss = criterion(predictions, target_videos)
        loss.backward()
        optimizer.step()

# 3. Semi-supervised learning - pseudo-labeling
# Generate pseudo-labels for the unlabeled data
unlabeled_dataset = VideoDataset("/scratch/dks7920/Dataset_Student/unlabeled")
unlabeled_dataloader = DataLoader(unlabeled_dataset, batch_size=32, shuffle=False)
segmentation_model.eval()
pseudo_labels = []
with torch.no_grad():
    for videos in unlabeled_dataloader:
        videos = videos.to(device)
        predictions = segmentation_model(videos[:, :11]) # Use first 11 frames
        pseudo_labels.append(predictions.argmax(dim=1).cpu())
        
combined_dataset = ConcatDataset([labeled_train_dataset] + [TensorDataset(videos, masks) for videos, masks in zip(unlabeled_dataset, pseudo_labels)])
combined_dataloader = DataLoader(combined_dataset, batch_size=16, shuffle=True)

for epoch in tqdm(range(num_epochs)):
# Training loop
    segmentation_model.train()
    for videos, masks in combined_dataloader:
        videos = videos.to(device)
        masks = masks.to(device)
        optimizer.zero_grad()
        predictions = segmentation_model(videos)
        loss = criterion(predictions, masks)
        loss.backward()
        optimizer.step()

        # Validation loop
segmentation_model.eval()
val_loss = 0
with torch.no_grad():
    for videos, masks in val_dataloader:
        videos = videos.to(device)
        masks = masks.to(device)
        predictions = segmentation_model(videos)
        loss = criterion(predictions, masks)
        val_loss += loss.item()

# Calculate average validation loss
avg_val_loss = val_loss / len(val_dataloader)
print(f"Epoch {epoch + 1}, Validation loss: {avg_val_loss:.4f}")
